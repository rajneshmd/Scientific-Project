# %% [markdown]
# # Final Code for Scientific Project (Crew Rostering) - **Initial Solution**

# %%
#Monday_data
#Step 1: Loading the Datasets
#First, we load both the railway data and the conductor availability data using Pandas.


import numpy as np
import pandas as pd
from collections import defaultdict

# Read data from Excel to dataframe
excel_file_path = 'weekly_trips_by_day_adjusted.xlsx'
monday_data = pd.read_excel(excel_file_path)

# Constants
MAX_WORKING_MINUTES = 600

# Conductor availability at each station
conductor_availability = {
    'A': 5,
    'B': 0,
    'C': 4,
    'D': 0,
    'E': 3,
    'F': 6,
    'G': 3,
    'H': 0,
    'I': 0,
    'J': 0,
    'K': 0,
    'L': 0
}

# Helper function to generate conductor names
def generate_conductor_name(station, count):
    return f"{count + 1}{station}"

# Function to calculate trip duration
def calculate_trip_duration(departure_time, arrival_time):
    return arrival_time - departure_time if arrival_time > departure_time else (1440 - departure_time) + arrival_time

# Adding trip duration to the dataframe
monday_data['trip_duration'] = monday_data.apply(lambda row: calculate_trip_duration(row['departure_time'], row['arrival_time']), axis=1)

# Resetting the conductor assignments and working minutes
conductor_working_minutes = {generate_conductor_name(station, i): 0 for station in conductor_availability for i in range(conductor_availability[station])}
conductor_last_trip_end_time = {name: None for name in conductor_working_minutes.keys()}

# Function to find a suitable conductor
def find_suitable_conductor(departure_station, trip_duration):
    for i in range(conductor_availability[departure_station]):
        conductor_name = generate_conductor_name(departure_station, i)
        if conductor_working_minutes[conductor_name] + trip_duration <= MAX_WORKING_MINUTES:
            return conductor_name
    return None

# Assigning conductors to trips based on the new rules
for train_number, trips in trips_by_train:
    last_conductor = None
    for _, trip in trips.iterrows():
        if trip['attendance_rate'] == 0:  # No conductor needed for 0% attendance rate
            continue

        # Find a suitable conductor
        conductor_name = find_suitable_conductor(trip['departure_station'], trip['trip_duration'])

        # If no conductor available at the departure station, check if the last conductor can continue
        if conductor_name is None and last_conductor and conductor_working_minutes[last_conductor] + trip['trip_duration'] <= MAX_WORKING_MINUTES:
            conductor_name = last_conductor

        if conductor_name:
            # Update conductor's working minutes
            conductor_working_minutes[conductor_name] += trip['trip_duration']

            # Assign conductor to the trip
            conductor_assignments[train_number].append({
                'trip_id': trip['id'],
                'conductor': conductor_name,
                'attendance_rate': trip['attendance_rate'],
                'departure_station': trip['departure_station'],
                'arrival_station': trip['arrival_station']
            })
            last_conductor = conductor_name  # Update last assigned conductor

# Populating the 'assigned_conductor' column in the original data with the new assignments
monday_data['assigned_conductor'] = np.nan  # Resetting the column
for train_number, assignments in conductor_assignments.items():
    for assignment in assignments:
        trip_id = assignment['trip_id']
        conductor_name = assignment['conductor']
        monday_data.loc[monday_data['id'] == trip_id, 'assigned_conductor'] = conductor_name

# Creating the new Excel file with the updated Monday data
new_monday_report_file_path = 'monday_trips_with_updated123_conductors.xlsx'
monday_data.to_excel(new_monday_report_file_path, index=False)

# %% [markdown]
# # Code for Heuristic
# ### Based on the shifted employees, the previous code was re-run to export the updated assignment of conductors

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# Read data from Excel to dataframe
excel_file_path = 'monday_data.xlsx'
monday_data = pd.read_excel(excel_file_path)

# Constants
MAX_WORKING_MINUTES = 600

# Conductor availability at each station
conductor_availability = {
    'A': 7,
    'B': 0,
    'C': 3,
    'D': 0,
    'E': 3,
    'F': 6,
    'G': 2,
    'H': 0,
    'I': 0,
    'J': 0,
    'K': 0,
    'L': 0
}

# Helper function to generate conductor names
def generate_conductor_name(station, count):
    return f"{count + 1}{station}"

# Function to calculate trip duration
def calculate_trip_duration(departure_time, arrival_time):
    return arrival_time - departure_time if arrival_time > departure_time else (1440 - departure_time) + arrival_time

# Adding trip duration to the dataframe
monday_data['trip_duration'] = monday_data.apply(lambda row: calculate_trip_duration(row['departure_time'], row['arrival_time']), axis=1)

# Resetting the conductor assignments and working minutes
conductor_working_minutes = {generate_conductor_name(station, i): 0 for station in conductor_availability for i in range(conductor_availability[station])}
conductor_last_trip_end_time = {name: None for name in conductor_working_minutes.keys()}

# Function to find a suitable conductor
def find_suitable_conductor(departure_station, trip_duration):
    for i in range(conductor_availability[departure_station]):
        conductor_name = generate_conductor_name(departure_station, i)
        if conductor_working_minutes[conductor_name] + trip_duration <= MAX_WORKING_MINUTES:
            return conductor_name
    return None

# Grouping the trips by train_number
trips_by_train = monday_data.groupby('train_number')
trips_by_train = {train_number: trips for train_number, trips in trips_by_train}

# Initializing the conductor assignments dictionary
conductor_assignments = defaultdict(list)

# Assigning conductors to trips based on the new rules
for train_number, trips in trips_by_train.items():
    last_conductor = None
    for _, trip in trips.iterrows():
        if trip['attendance_rate'] == 0:  # No conductor needed for 0% attendance rate
            continue

        # Find a suitable conductor
        conductor_name = find_suitable_conductor(trip['departure_station'], trip['trip_duration'])

        # If no conductor available at the departure station, check if the last conductor can continue
        if conductor_name is None and last_conductor and conductor_working_minutes[last_conductor] + trip['trip_duration'] <= MAX_WORKING_MINUTES:
            conductor_name = last_conductor

        if conductor_name:
            # Update conductor's working minutes
            conductor_working_minutes[conductor_name] += trip['trip_duration']

            # Assign conductor to the trip
            conductor_assignments[train_number].append({
                'trip_id': trip['id'],
                'conductor': conductor_name,
                'attendance_rate': trip['attendance_rate'],
                'departure_station': trip['departure_station'],
                'arrival_station': trip['arrival_station']
            })
            last_conductor = conductor_name  # Update last assigned conductor

# Populating the 'assigned_conductor' column in the original data with the new assignments
monday_data['assigned_conductor'] = np.nan  # Resetting the column
for train_number, assignments in conductor_assignments.items():
    for assignment in assignments:
        trip_id = assignment['trip_id']
        conductor_name = assignment['conductor']
        monday_data.loc[monday_data['id'] == trip_id, 'assigned_conductor'] = conductor_name

# Creating the new Excel file with the updated Monday data
new_monday_report_file_path = 'iteration_5_variation_17.xlsx'
monday_data.to_excel(new_monday_report_file_path, index=False)

# %% [markdown]
# ### Rough Work (Trying OOP for DB Crew Rostering)
#
# #####The following code was only rough work to try attempting OOP in the problem, however the scope was changed and it was discarded.

# %%
# Part 1

import pandas as pd


class Trip:
    def __init__(self, departure_station,
                 arrival_station,
                 departure_time,
                 arrival_time,
                 travel_time,
                 train_number,
                 attendance_rate,
                 days,
                 available_conductors):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.travel_time = travel_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.available_conductors = available_conductors
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor


    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, travel_time={self.travel_time},train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, available_conductors={self.available_conductors},assigned_conductor={self.assigned_conductor})"



# Read data from Excel to dataframe
excel_file_path = 'allday_railway_Mon.xlsx'
df = pd.read_excel(excel_file_path)

# Create instances of the Trip class from dataframe rows
trips = []
for index, row in df.iterrows():
    # Split the 'days' string into a list
    days_list = row['days'].split(', ')

    for day in days_list:

       trip = Trip(
          departure_station=row['departure_station'],
          arrival_station=row['arrival_station'],
          departure_time=row['departure_time'],
          arrival_time=row['arrival_time'],
          travel_time=row['arrival_time'] - row['departure_time'],
          train_number=row['train_number'],
          attendance_rate=row['attendance_rate'],
          days= day,
          available_conductors=[row['available_conductors']])
    trips.append(trip)

for trip in trips:
 print(trip)
# Out:
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=384, arrival_time=409, travel_time=25,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=384, arrival_time=400, travel_time=16,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=385, arrival_time=418, travel_time=33,train_number=22, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, travel_time=27,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=387, arrival_time=394, travel_time=7,train_number=23, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, travel_time=15,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=390, arrival_time=401, travel_time=11,train_number=24, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=L, arrival_station=A, departure_time=392, arrival_time=406, travel_time=14,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=393, arrival_time=403, travel_time=10,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=394, arrival_time=414, travel_time=20,train_number=21, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=397, arrival_time=420, travel_time=23,train_number=26, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=397, arrival_time=402, travel_time=5,train_number=27, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, travel_time=10,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=401, arrival_time=427, travel_time=26,train_number=24, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=402, arrival_time=416, travel_time=14,train_number=27, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, travel_time=12,train_number=5, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=405, arrival_time=415, travel_time=10,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, travel_time=2,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=409, arrival_time=420, travel_time=11,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=411, arrival_time=437, travel_time=26,train_number=20, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=411, arrival_time=422, travel_time=11,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, travel_time=16,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=415, arrival_time=446, travel_time=31,train_number=28, attendance_rate=0.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=415, arrival_time=419, travel_time=4,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=416, arrival_time=443, travel_time=27,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=417, arrival_time=437, travel_time=20,train_number=27, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=419, arrival_time=428, travel_time=9,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=419, arrival_time=450, travel_time=31,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, travel_time=26,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=420, arrival_time=433, travel_time=13,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=420, arrival_time=431, travel_time=11,train_number=30, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=423, arrival_time=437, travel_time=14,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=453, travel_time=30,train_number=31, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=423, arrival_time=431, travel_time=8,train_number=32, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=424, arrival_time=444, travel_time=20,train_number=33, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, travel_time=13,train_number=3, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=429, arrival_time=441, travel_time=12,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=431, arrival_time=458, travel_time=27,train_number=30, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=433, arrival_time=443, travel_time=10,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=436, arrival_time=443, travel_time=7,train_number=34, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=438, arrival_time=453, travel_time=15,train_number=20, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=438, arrival_time=441, travel_time=3,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=438, arrival_time=450, travel_time=12,train_number=20, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=L, departure_time=439, arrival_time=448, travel_time=9,train_number=27, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=441, arrival_time=451, travel_time=10,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=441, arrival_time=451, travel_time=10,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=443, arrival_time=446, travel_time=3,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=444, arrival_time=460, travel_time=16,train_number=33, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, travel_time=27,train_number=9, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=447, arrival_time=461, travel_time=14,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=451, arrival_time=481, travel_time=30,train_number=13, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=451, arrival_time=475, travel_time=24,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=452, arrival_time=475, travel_time=23,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=454, arrival_time=474, travel_time=20,train_number=20, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=457, arrival_time=468, travel_time=11,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=L, arrival_station=A, departure_time=457, arrival_time=471, travel_time=14,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=461, arrival_time=468, travel_time=7,train_number=36, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=462, arrival_time=474, travel_time=12,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=465, arrival_time=492, travel_time=27,train_number=31, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=470, arrival_time=480, travel_time=10,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=476, arrival_time=486, travel_time=10,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=477, arrival_time=492, travel_time=15,train_number=12, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=479, arrival_time=510, travel_time=31,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=481, arrival_time=508, travel_time=27,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=481, arrival_time=489, travel_time=8,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=482, arrival_time=507, travel_time=25,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=483, arrival_time=509, travel_time=26,train_number=38, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=484, arrival_time=504, travel_time=20,train_number=39, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=486, arrival_time=499, travel_time=13,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=490, arrival_time=504, travel_time=14,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=492, arrival_time=499, travel_time=7,train_number=40, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=494, arrival_time=505, travel_time=11,train_number=41, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=498, arrival_time=513, travel_time=15,train_number=42, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=499, arrival_time=509, travel_time=10,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=503, arrival_time=528, travel_time=25,train_number=31, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=505, arrival_time=532, travel_time=27,train_number=41, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=505, arrival_time=508, travel_time=3,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=508, arrival_time=534, travel_time=26,train_number=18, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=509, arrival_time=519, travel_time=10,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=509, arrival_time=512, travel_time=3,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=510, arrival_time=537, travel_time=27,train_number=38, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=511, arrival_time=535, travel_time=24,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=511, arrival_time=541, travel_time=30,train_number=25, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=513, arrival_time=527, travel_time=14,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=514, arrival_time=534, travel_time=20,train_number=42, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=516, arrival_time=526, travel_time=10,train_number=43, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, travel_time=16,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=519, arrival_time=530, travel_time=11,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, travel_time=7,train_number=45, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=528, arrival_time=541, travel_time=13,train_number=29, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=529, arrival_time=540, travel_time=11,train_number=31, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=530, arrival_time=540, travel_time=10,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=536, arrival_time=546, travel_time=10,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, travel_time=31,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=541, arrival_time=568, travel_time=27,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, travel_time=8,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=541, arrival_time=567, travel_time=26,train_number=38, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=542, arrival_time=567, travel_time=25,train_number=41, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, travel_time=25,train_number=47, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, travel_time=8,train_number=48, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, travel_time=20,train_number=49, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=546, arrival_time=559, travel_time=13,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, travel_time=14,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, travel_time=11,train_number=50, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=559, arrival_time=569, travel_time=10,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, travel_time=27,train_number=50, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, travel_time=3,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=568, arrival_time=580, travel_time=12,train_number=38, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=568, arrival_time=594, travel_time=26,train_number=41, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=569, arrival_time=572, travel_time=3,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, travel_time=10,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, travel_time=27,train_number=47, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, travel_time=24,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=571, arrival_time=601, travel_time=30,train_number=35, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=573, arrival_time=587, travel_time=14,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, travel_time=20,train_number=51, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, travel_time=11,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, travel_time=7,train_number=52, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=588, arrival_time=601, travel_time=13,train_number=37, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, travel_time=10,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, travel_time=10,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=599, arrival_time=630, travel_time=31,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=601, arrival_time=609, travel_time=8,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, travel_time=26,train_number=47, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, travel_time=27,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, travel_time=25,train_number=50, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=603, arrival_time=611, travel_time=8,train_number=55, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=603, arrival_time=628, travel_time=25,train_number=56, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=604, arrival_time=624, travel_time=20,train_number=57, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, travel_time=13,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=610, arrival_time=624, travel_time=14,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=614, arrival_time=625, travel_time=11,train_number=58, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, travel_time=10,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=625, arrival_time=628, travel_time=3,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=625, arrival_time=652, travel_time=27,train_number=58, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, travel_time=26,train_number=50, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, travel_time=12,train_number=47, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, travel_time=3,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=629, arrival_time=656, travel_time=27,train_number=56, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=629, arrival_time=639, travel_time=10,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, travel_time=30,train_number=44, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=631, arrival_time=655, travel_time=24,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, travel_time=14,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=634, arrival_time=654, travel_time=20,train_number=59, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=639, arrival_time=650, travel_time=11,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=641, arrival_time=648, travel_time=7,train_number=60, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, travel_time=13,train_number=46, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=650, arrival_time=660, travel_time=10,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=656, arrival_time=666, travel_time=10,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=659, arrival_time=690, travel_time=31,train_number=61, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=661, arrival_time=687, travel_time=26,train_number=56, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=661, arrival_time=688, travel_time=27,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=661, arrival_time=669, travel_time=8,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=662, arrival_time=687, travel_time=25,train_number=58, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=663, arrival_time=671, travel_time=8,train_number=63, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=663, arrival_time=688, travel_time=25,train_number=64, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=664, arrival_time=684, travel_time=20,train_number=65, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=666, arrival_time=679, travel_time=13,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=670, arrival_time=684, travel_time=14,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=674, arrival_time=685, travel_time=11,train_number=66, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=679, arrival_time=689, travel_time=10,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=685, arrival_time=688, travel_time=3,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=685, arrival_time=712, travel_time=27,train_number=66, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=688, arrival_time=714, travel_time=26,train_number=58, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=688, arrival_time=700, travel_time=12,train_number=56, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=689, arrival_time=716, travel_time=27,train_number=64, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=689, arrival_time=692, travel_time=3,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=689, arrival_time=699, travel_time=10,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=691, arrival_time=721, travel_time=30,train_number=54, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=691, arrival_time=715, travel_time=24,train_number=61, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=693, arrival_time=707, travel_time=14,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=694, arrival_time=714, travel_time=20,train_number=67, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=699, arrival_time=710, travel_time=11,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=701, arrival_time=708, travel_time=7,train_number=68, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=708, arrival_time=721, travel_time=13,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=710, arrival_time=720, travel_time=10,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=716, arrival_time=726, travel_time=10,train_number=61, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=719, arrival_time=750, travel_time=31,train_number=69, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=721, arrival_time=747, travel_time=26,train_number=64, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=721, arrival_time=748, travel_time=27,train_number=62, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=721, arrival_time=729, travel_time=8,train_number=70, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=722, arrival_time=747, travel_time=25,train_number=66, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=723, arrival_time=738, travel_time=15,train_number=53, attendance_rate=0.5, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=723, arrival_time=731, travel_time=8,train_number=71, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=723, arrival_time=748, travel_time=25,train_number=72, attendance_rate=0.5, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=724, arrival_time=744, travel_time=20,train_number=73, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=726, arrival_time=739, travel_time=13,train_number=61, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=730, arrival_time=744, travel_time=14,train_number=70, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=734, arrival_time=744, travel_time=10,train_number=74, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=734, arrival_time=745, travel_time=11,train_number=75, attendance_rate=0.5, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=739, arrival_time=749, travel_time=10,train_number=61, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=744, arrival_time=760, travel_time=16,train_number=73, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=745, arrival_time=772, travel_time=27,train_number=75, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=745, arrival_time=748, travel_time=3,train_number=70, attendance_rate=0.5, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=L, arrival_station=A, departure_time=748, arrival_time=760, travel_time=12,train_number=76, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=748, arrival_time=774, travel_time=26,train_number=66, attendance_rate=0.5, days=Mo, available_conductors=[6],assigned_conductor=None)
# ...
# Trip(departure_station=H, arrival_station=J, departure_time=1219, arrival_time=1229, travel_time=10,train_number=134, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=1225, arrival_time=1228, travel_time=3,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=1228, arrival_time=1254, travel_time=26,train_number=142, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1229, arrival_time=1256, travel_time=27,train_number=144, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=1229, arrival_time=1239, travel_time=10,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=1229, arrival_time=1232, travel_time=3,train_number=134, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1231, arrival_time=1255, travel_time=24,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1231, arrival_time=1261, travel_time=30,train_number=133, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=1233, arrival_time=1247, travel_time=14,train_number=134, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=1234, arrival_time=1254, travel_time=20,train_number=146, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=1239, arrival_time=1250, travel_time=11,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=1241, arrival_time=1248, travel_time=7,train_number=147, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1248, arrival_time=1261, travel_time=13,train_number=134, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=1250, arrival_time=1260, travel_time=10,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1256, arrival_time=1266, travel_time=10,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1259, arrival_time=1290, travel_time=31,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=1261, arrival_time=1288, travel_time=27,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1261, arrival_time=1269, travel_time=8,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1262, arrival_time=1287, travel_time=25,train_number=150, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1263, arrival_time=1271, travel_time=8,train_number=151, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1264, arrival_time=1284, travel_time=20,train_number=152, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=1266, arrival_time=1279, travel_time=13,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1270, arrival_time=1284, travel_time=14,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=1279, arrival_time=1289, travel_time=10,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=1285, arrival_time=1288, travel_time=3,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=1288, arrival_time=1317, travel_time=29,train_number=150, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=1289, arrival_time=1292, travel_time=3,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=1289, arrival_time=1299, travel_time=10,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1291, arrival_time=1315, travel_time=24,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1291, arrival_time=1321, travel_time=30,train_number=141, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=1293, arrival_time=1307, travel_time=14,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=1294, arrival_time=1314, travel_time=20,train_number=153, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=1299, arrival_time=1310, travel_time=11,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=1301, arrival_time=1308, travel_time=7,train_number=154, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1308, arrival_time=1321, travel_time=13,train_number=140, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=1310, arrival_time=1320, travel_time=10,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1316, arrival_time=1326, travel_time=10,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1321, arrival_time=1351, travel_time=30,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1321, arrival_time=1329, travel_time=8,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=1321, arrival_time=1348, travel_time=27,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1322, arrival_time=1347, travel_time=25,train_number=157, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=1323, arrival_time=1349, travel_time=26,train_number=158, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1323, arrival_time=1331, travel_time=8,train_number=159, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1324, arrival_time=1344, travel_time=20,train_number=160, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=1326, arrival_time=1339, travel_time=13,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1330, arrival_time=1344, travel_time=14,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=1339, arrival_time=1349, travel_time=10,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=1345, arrival_time=1348, travel_time=3,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=1348, arrival_time=1377, travel_time=29,train_number=157, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=1349, arrival_time=1352, travel_time=3,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=1349, arrival_time=1359, travel_time=10,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1350, arrival_time=1377, travel_time=27,train_number=158, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1351, arrival_time=1381, travel_time=30,train_number=149, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1352, arrival_time=1376, travel_time=24,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=1353, arrival_time=1367, travel_time=14,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=1354, arrival_time=1374, travel_time=20,train_number=161, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=1359, arrival_time=1370, travel_time=11,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1368, arrival_time=1381, travel_time=13,train_number=148, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=1370, arrival_time=1380, travel_time=10,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1377, arrival_time=1387, travel_time=10,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1379, arrival_time=1410, travel_time=31,train_number=162, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=1381, arrival_time=1408, travel_time=27,train_number=156, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1383, arrival_time=1391, travel_time=8,train_number=163, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=1383, arrival_time=1409, travel_time=26,train_number=164, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1384, arrival_time=1404, travel_time=20,train_number=165, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=1387, arrival_time=1399, travel_time=12,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[4],assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=1396, arrival_time=1403, travel_time=7,train_number=166, attendance_rate=0.0, days=Mo, available_conductors=[5],assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=1400, arrival_time=1409, travel_time=9,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=1409, arrival_time=1412, travel_time=3,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1410, arrival_time=1437, travel_time=27,train_number=164, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1411, arrival_time=1435, travel_time=24,train_number=162, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1413, arrival_time=1445, travel_time=32,train_number=167, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=1413, arrival_time=1427, travel_time=14,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1428, arrival_time=1441, travel_time=13,train_number=155, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Mo, available_conductors=[0],assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Mo, available_conductors=[6],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Mo, available_conductors=[3],assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Mo, available_conductors=[0],assigned_conductor=None)

# %%
# Crew Rostering for DB Regio

import pandas as pd


class Trip:
    def __init__(self, departure_station,
                 arrival_station,
                 departure_time,
                 arrival_time,
                 travel_time,
                 train_number,
                 attendance_rate,
                 days,
                 available_conductors):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.travel_time = travel_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.available_conductors = available_conductors
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor

    def assign_conductors(self):
        current_conductor_index = 0
        cumulative_travel_time = 0

        while cumulative_travel_time < self.travel_time:
            if self.available_conductors[current_conductor_index] > 0:
                self.assign_conductor(current_conductor_index)
                self.available_conductors[current_conductor_index] -= 1

                # Accumulate travel time for each assignment
                cumulative_travel_time += self.travel_time

                # Check if the accumulated travel time is within the specified range
                if cumulative_travel_time >= 550 and cumulative_travel_time <= 600:
                    current_conductor_index = (current_conductor_index + 1) % len(self.available_conductors)
                    cumulative_travel_time = 0
                elif self.arrival_station == self.departure_station:
                    current_conductor_index = (current_conductor_index + 1) % len(self.available_conductors)
                    cumulative_travel_time = 0
            else:
                current_conductor_index = (current_conductor_index + 1) % len(self.available_conductors)


    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, travel_time={self.travel_time},train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, available_conductors={self.available_conductors},assigned_conductor={self.assigned_conductor})"



# Read data from Excel to dataframe
excel_file_path = 'allday_railway_Mon.xlsx'
df = pd.read_excel(excel_file_path)

# Create instances of the Trip class from dataframe rows
trips = []
for index, row in df.iterrows():
    # Split the 'days' string into a list
    days_list = row['days'].split(', ')

    for day in days_list:

       trip = Trip(
          departure_station=row['departure_station'],
          arrival_station=row['arrival_station'],
          departure_time=row['departure_time'],
          arrival_time=row['arrival_time'],
          travel_time=row['arrival_time'] - row['departure_time'],
          train_number=row['train_number'],
          attendance_rate=row['attendance_rate'],
          days= day,
          available_conductors=[row['available_conductors']])
    trip.assign_conductors() # assign conductors for the trip
    trips.append(trip)

for trip in trips:
 print(trip)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c29d1fc93b1d> in <cell line: 71>()
#      85           days= day,
#      86           available_conductors=[row['available_conductors']])
# ---> 87     trip.assign_conductors() # assign conductors for the trip
#      88     trips.append(trip)
#      89
#
# <ipython-input-12-c29d1fc93b1d> in assign_conductors(self)
#      50                     cumulative_travel_time = 0
#      51             else:
# ---> 52                 current_conductor_index = (current_conductor_index + 1) % len(self.available_conductors)
#      53
#      54 # ... (remaining code)
#
# KeyboardInterrupt:

# %% [markdown]
# Create Class for Conductor

# %%
# make another class for available conductors

class Conductor:
    def __init__(self, stationName, crewBase, days, employees):
        self.stationName = stationName
        self.crewBase = crewBase
        # Handle NaN values
        if pd.notna(days):
            self.days = [str(x) for x in str(days).strip('[]').split(',')]
        else:
            self.days = []
          # Handle NaN values
        if pd.notna(employees):
            self.employees = [int(x) for x in str(employees).strip('[]').split(',')]
        else:
            self.employees = []

    def __repr__(self):
      return f"Conductor(stationName={self.stationName},crewBase={self.crewBase}, "\
             f"days={self.days}, conductors={self.employees}, "

# Read data from Excel to dataframe
excel_file_path = 'available_conductors.xlsx'
df = pd.read_excel(excel_file_path)

# Convert column names to lowercase
df.columns = df.columns.str.lower()

# Print actual column names
print(df.columns)


# Create instances of the Employee class from dataframe rows
conductors = []
for index, row in df.iterrows():
    # Check for NaN values in 'days' column
    if pd.notna(row['days']):
        days_list = row['days'].split(', ')
    else:
        days_list = []
    if pd.notna(row['employees']):
        employees_list = row['employees'].split(', ')
    else:
        employees_list = []

    # Iterate over days and employees, associating each conductor with a specific day
    for day, conductor_count in zip(days_list, employees_list):
        conductor = Conductor(row['name'], row['crewbase'], day, conductor_count)
        conductors.append(conductor)


for conductor in conductors:
  print(conductor)
# Out:
# Index(['name', 'crewbase', 'employees', 'days'], dtype='object')
# Conductor(stationName=A,crewBase=True, days=['Mo'], conductors=[5],
# Conductor(stationName=A,crewBase=True, days=['Tu'], conductors=[5],
# Conductor(stationName=A,crewBase=True, days=['We'], conductors=[5],
# Conductor(stationName=A,crewBase=True, days=['Th'], conductors=[5],
# Conductor(stationName=A,crewBase=True, days=['Fr'], conductors=[5],
# Conductor(stationName=A,crewBase=True, days=['Sa'], conductors=[3],
# Conductor(stationName=A,crewBase=True, days=['Su'], conductors=[3],
# Conductor(stationName=B,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=B,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=C,crewBase=True, days=['Mo'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['Tu'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['We'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['Th'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['Fr'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['Sa'], conductors=[4],
# Conductor(stationName=C,crewBase=True, days=['Su'], conductors=[4],
# Conductor(stationName=D,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=D,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=E,crewBase=True, days=['Mo'], conductors=[3],
# Conductor(stationName=E,crewBase=True, days=['Tu'], conductors=[3],
# Conductor(stationName=E,crewBase=True, days=['We'], conductors=[3],
# Conductor(stationName=E,crewBase=True, days=['Th'], conductors=[3],
# Conductor(stationName=E,crewBase=True, days=['Fr'], conductors=[3],
# Conductor(stationName=E,crewBase=True, days=['Sa'], conductors=[2],
# Conductor(stationName=E,crewBase=True, days=['Su'], conductors=[2],
# Conductor(stationName=F,crewBase=True, days=['Mo'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['Tu'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['We'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['Th'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['Fr'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['Sa'], conductors=[6],
# Conductor(stationName=F,crewBase=True, days=['Su'], conductors=[6],
# Conductor(stationName=G,crewBase=True, days=['Mo'], conductors=[3],
# Conductor(stationName=G,crewBase=True, days=['Tu'], conductors=[3],
# Conductor(stationName=G,crewBase=True, days=['We'], conductors=[3],
# Conductor(stationName=G,crewBase=True, days=['Th'], conductors=[3],
# Conductor(stationName=G,crewBase=True, days=['Fr'], conductors=[3],
# Conductor(stationName=G,crewBase=True, days=['Sa'], conductors=[1],
# Conductor(stationName=G,crewBase=True, days=['Su'], conductors=[1],
# Conductor(stationName=H,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=H,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=I,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=J,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=K,crewBase=False, days=['Su'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Mo'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Tu'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['We'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Th'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Fr'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Sa'], conductors=[0],
# Conductor(stationName=L,crewBase=False, days=['Su'], conductors=[0],

# %% [markdown]
# Define Functions (Conductor Assignment,...)

# %%
import pandas as pd
from datetime import datetime, timedelta

class Trip:
    def __init__(self, departure_station,
                 arrival_station,
                 departure_time,
                 arrival_time,
                 travel_time,
                 train_number,
                 attendance_rate,
                 days):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.travel_time = travel_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor

    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, travel_time={self.travel_time},train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, assigned_conductor={self.assigned_conductor})"


class Conductor:
    def __init__(self, stationName, crewBase, days, employees):
        self.stationName = stationName
        self.crewBase = crewBase
        # Handle NaN values
        if pd.notna(days):
            self.days = [str(x) for x in str(days).strip('[]').split(',')]
        else:
            self.days = []
          # Handle NaN values
        if pd.notna(employees):
            self.employees = [int(x) for x in str(employees).strip('[]').split(',')]
        else:
            self.employees = []

    def __repr__(self):
      return f"Conductor(stationName={self.stationName},crewBase={self.crewBase}, "\
             f"days={self.days}, conductors={self.employees}, "


def assign_conductors_to_trips():
  for trip in trips:
    # find the available conductors from departing station on that day
    available_conductors = [conductor for conductor in conductors if
                            conductor.stationName == trip.departure_station and trip.days[0] in conductor.days and
                            conductor.employees > 0]

    if available_conductors:
      assigned_conductor = available_conductors.pop(0) # assigning the first available conductor
      assigned_conductor.employees -= 1 # Deduct 1 from available conductors
      trip.assign_conductor(assigned_conductor)



# Read data from Excel to dataframe
trip_excel_file_path = 'allday_railway.xlsx'
conductor_excel_file_path = 'available_conductors.xlsx'
trip_df = pd.read_excel(trip_excel_file_path)
conductor_df = pd.read_excel(conductor_excel_file_path)

# Create instances of the Trip class from dataframe rows
trips = []
for index, row in trip_df.iterrows():
    days_list = row['days'].split(', ')
    for day in days_list:
        trip = Trip(row['departure_station'], row['arrival_station'],
                    row['departure_time'], row['arrival_time'],
                    row['arrival_time'] - row['departure_time'], row['train_number'],
                    row['attendance_rate'], day)
        trips.append(trip)

# Create instances of the Conductor class from dataframe rows
conductors = []
for index, row in conductor_df.iterrows():
    if pd.notna(row['days']):
        days_list = row['days'].split(', ')
    else:
        days_list = []
    if pd.notna(row['employees']):
        employees_list = row['employees'].split(', ')
    else:
        employees_list = []

    for day, conductor_count in zip(days_list, employees_list):
        conductor = Conductor(row['name'], row['crewBase'], day, conductor_count)
        conductors.append(conductor)

# Assign conductors to trips
assign_conductors_to_trips()

# Print assigned trips
for trip in trips:
    print(trip)
# Out:
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, travel_time=7,train_number=1, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, travel_time=11,train_number=2, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, travel_time=35,train_number=3, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, travel_time=30,train_number=4, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, travel_time=27,train_number=2, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, travel_time=31,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, travel_time=7,train_number=6, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, travel_time=32,train_number=2, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, travel_time=11,train_number=7, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, travel_time=37,train_number=3, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, travel_time=15,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, travel_time=27,train_number=7, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, travel_time=9,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, travel_time=10,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, travel_time=24,train_number=5, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, travel_time=29,train_number=4, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, travel_time=16,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, travel_time=3,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, travel_time=20,train_number=10, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, travel_time=14,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, travel_time=23,train_number=11, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, travel_time=31,train_number=12, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, travel_time=10,train_number=5, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, travel_time=22,train_number=3, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, travel_time=2,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, travel_time=11,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, travel_time=8,train_number=13, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, travel_time=11,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, travel_time=29,train_number=7, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, travel_time=7,train_number=14, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, travel_time=13,train_number=5, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, travel_time=7,train_number=15, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, travel_time=16,train_number=13, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, travel_time=11,train_number=16, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, travel_time=12,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, travel_time=35,train_number=17, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, travel_time=14,train_number=8, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, travel_time=20,train_number=18, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, travel_time=25,train_number=19, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, travel_time=14,train_number=3, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, travel_time=27,train_number=16, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, travel_time=33,train_number=20, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, travel_time=9,train_number=5, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=378, arrival_time=393, travel_time=15,train_number=21, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=378, arrival_time=381, travel_time=3,train_number=13, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, travel_time=30,train_number=7, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=382, arrival_time=392, travel_time=10,train_number=13, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, travel_time=16,train_number=3, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=We, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Th, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Fr, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, travel_time=3,train_number=5, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=384, arrival_time=409, travel_time=25,train_number=12, attendance_rate=0.5, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=384, arrival_time=409, travel_time=25,train_number=12, attendance_rate=0.5, days=Tu, assigned_conductor=None)
# ...
# Trip(departure_station=I, arrival_station=A, departure_time=1428, arrival_time=1441, travel_time=13,train_number=155, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1428, arrival_time=1441, travel_time=13,train_number=155, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=1428, arrival_time=1441, travel_time=13,train_number=155, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1436, arrival_time=1446, travel_time=10,train_number=162, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=We, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Th, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, travel_time=8,train_number=168, attendance_rate=0.0, days=Su, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=We, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Th, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, travel_time=32,train_number=169, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, travel_time=32,train_number=170, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=We, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Th, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, travel_time=24,train_number=169, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Mo, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Tu, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=We, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Th, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, travel_time=10,train_number=169, attendance_rate=1.0, days=Su, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, travel_time=20,train_number=171, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, travel_time=20,train_number=171, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, travel_time=10,train_number=172, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, travel_time=10,train_number=172, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, travel_time=16,train_number=171, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, travel_time=16,train_number=171, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, travel_time=20,train_number=173, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, travel_time=20,train_number=173, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, travel_time=23,train_number=174, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, travel_time=23,train_number=174, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, travel_time=10,train_number=175, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, travel_time=10,train_number=175, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, travel_time=20,train_number=176, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, travel_time=20,train_number=176, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, travel_time=16,train_number=175, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, travel_time=16,train_number=175, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, travel_time=7,train_number=177, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, travel_time=7,train_number=177, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, travel_time=2,train_number=175, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, travel_time=2,train_number=175, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, travel_time=16,train_number=176, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, travel_time=16,train_number=176, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, travel_time=10,train_number=175, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, travel_time=10,train_number=175, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, travel_time=15,train_number=175, attendance_rate=1.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, travel_time=15,train_number=175, attendance_rate=1.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, travel_time=23,train_number=178, attendance_rate=0.0, days=Fr, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, travel_time=23,train_number=178, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, travel_time=10,train_number=179, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, travel_time=10,train_number=179, attendance_rate=0.0, days=Su, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, travel_time=10,train_number=9, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, travel_time=27,train_number=9, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, travel_time=20,train_number=180, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, travel_time=20,train_number=180, attendance_rate=0.0, days=Su, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, travel_time=26,train_number=9, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, travel_time=26,train_number=9, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, travel_time=29,train_number=31, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, travel_time=29,train_number=31, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=423, arrival_time=431, travel_time=8,train_number=181, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, travel_time=27,train_number=9, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, travel_time=27,train_number=9, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, travel_time=29,train_number=31, attendance_rate=0.5, days=Sa, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, travel_time=29,train_number=31, attendance_rate=0.5, days=Su, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, travel_time=15,train_number=182, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, travel_time=15,train_number=182, attendance_rate=0.0, days=Su, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, travel_time=8,train_number=183, attendance_rate=0.0, days=Sa, assigned_conductor=None)
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, travel_time=8,train_number=183, attendance_rate=0.0, days=Su, assigned_conductor=None)

# %%
class Employee:
    def __init__(self, stationName, crewBase, breakPossible, employees, partTimeEmployees):
        self.stationName = stationName
        self.crewBase = crewBase
        self.breakPossible = breakPossible
        self.employees = employees
        self.partTimeEmployees = partTimeEmployees

    def __repr__(self):
      return f"Employee(stationName={self.stationName},crewBase={self.crewBase}, "\
             f"breakPossible={self.breakPossible}, employees={self.employees}, "\
             f"partTimeEmployees={self.partTimeEmployees})"

# Read data from Excel to dataframe
excel_file_path = 'stations_2.xlsx'
df = pd.read_excel(excel_file_path)

# Convert column names to lowercase
df.columns = df.columns.str.lower()

# Print actual column names
print(df.columns)

# Create instances of the Employee class from dataframe rows
employees = []
for index, row in df.iterrows():
    employee = Employee(row['name'],
                        row['crewbase'],
                        row['breakpossible'],
                        row['employees'],
                        row['parttimeemployees'])
    employees.append(employee)


print(employees)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd64ed0bf2b4> in <cell line: 16>()
#      14 # Read data from Excel to dataframe
#      15 excel_file_path = 'stations_2.xlsx'
# ---> 16 df = pd.read_excel(excel_file_path)
#      17
#      18 # Convert column names to lowercase
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Building on to Shafaq's code. Following things to add
#
# 1. Conductors time limit (10 hours)
# 2. Move to next conductor after attendance rate is reached
# 3. Visualization of conductor assignment

# %%
#assignment of conductors without considering attendance rate
import pandas as pd

class Trip:
    def __init__(self, departure_station, arrival_station, departure_time, arrival_time, train_number, attendance_rate, days, conductors_available):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.conductors_available = str(conductors_available)  # Convert to string
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor

    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, conductors_available={self.conductors_available}, assigned_conductor={self.assigned_conductor})"

class Conductor:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f"Conductor(name={self.name})"

def assign_conductors_to_trips(trips):
    for trip in trips:
        # Find available conductors for the departing station on the given day
        available_conductors = [Conductor(name) for name in trip.conductors_available.split(',')]

        # Assign the first available conductor to the trip
        if available_conductors:
            trip.assign_conductor(available_conductors[0])

# Read data from Excel to dataframe
excel_file_path = 'allday_railway_transformed.xlsx'
df = pd.read_excel(excel_file_path)

# Create instances of the Trip class from dataframe rows
trips = []
for index, row in df.iterrows():
    trip = Trip(row['departure_station'],
                row['arrival_station'],
                row['departure_time'],
                row['arrival_time'],
                row['train_number'],
                row['attendance_rate'],
                row['days'],
                row['conductors_available'])
    trips.append(trip)

# Assign conductors to trips based on available conductors at the departing station on that day
assign_conductors_to_trips(trips)

# Print the updated trips list with assigned conductors
for trip in trips:
    print(trip)
# Out:
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=We, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, train_number=10, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, train_number=10, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, train_number=10, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, train_number=10, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=334, arrival_time=354, train_number=10, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, train_number=11, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, train_number=11, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, train_number=11, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, train_number=11, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=K, departure_time=337, arrival_time=360, train_number=11, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=342, arrival_time=373, train_number=12, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, train_number=13, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, train_number=13, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, train_number=13, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, train_number=13, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=350, arrival_time=358, train_number=13, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, train_number=14, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, train_number=14, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, train_number=14, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, train_number=14, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=355, arrival_time=362, train_number=14, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, train_number=15, attendance_rate=0.0, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, train_number=15, attendance_rate=0.0, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, train_number=15, attendance_rate=0.0, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, train_number=15, attendance_rate=0.0, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=358, arrival_time=365, train_number=15, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, train_number=13, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, train_number=13, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, train_number=13, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, train_number=13, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=360, arrival_time=376, train_number=13, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=360, arrival_time=371, train_number=16, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, train_number=17, attendance_rate=0.0, days=Mo, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, train_number=17, attendance_rate=0.0, days=Tu, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, train_number=17, attendance_rate=0.0, days=We, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, train_number=17, attendance_rate=0.0, days=Th, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=362, arrival_time=397, train_number=17, attendance_rate=0.0, days=Fr, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, train_number=18, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, train_number=18, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, train_number=18, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, train_number=18, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=364, arrival_time=384, train_number=18, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, train_number=19, attendance_rate=0.0, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, train_number=19, attendance_rate=0.0, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, train_number=19, attendance_rate=0.0, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, train_number=19, attendance_rate=0.0, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=J, departure_time=365, arrival_time=390, train_number=19, attendance_rate=0.0, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=G, departure_time=371, arrival_time=398, train_number=16, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=372, arrival_time=405, train_number=20, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# ...
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, train_number=168, attendance_rate=0.0, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, train_number=168, attendance_rate=0.0, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, train_number=168, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, train_number=168, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=1443, arrival_time=1451, train_number=168, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Su, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=B, arrival_station=A, departure_time=423, arrival_time=431, train_number=181, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))

# %%
# for journeys creation - easy to read data

import pandas as pd
import random

class Trip:
    def __init__(self, departure_station, arrival_station, departure_time, arrival_time, train_number, attendance_rate, days, conductors_available):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.conductors_available = str(conductors_available)  # Convert to string
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor

    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, conductors_available={self.conductors_available}, assigned_conductor={self.assigned_conductor})"

class Conductor:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f"Conductor(name={self.name})"

def assign_conductors_to_trips(trips):
    for trip in trips:
        # Check if a conductor should be assigned based on attendance rate
        if random.random() < trip.attendance_rate:
            # Find available conductors for the departing station on the given day
            available_conductors = [Conductor(name) for name in trip.conductors_available.split(',')]

            # Assign a random available conductor to the trip
            if available_conductors:
                trip.assign_conductor(random.choice(available_conductors))

def create_journeys(trips):
    journeys = []
    current_journey = []

    for trip in trips:
        if not current_journey or current_journey[-1].arrival_station == trip.departure_station:
            current_journey.append(trip)
        else:
            journeys.append(current_journey)
            current_journey = [trip]

    if current_journey:
        journeys.append(current_journey)

    return journeys

# Read data from Excel to dataframe
excel_file_path = 'allday_railway_transformed.xlsx'
df = pd.read_excel(excel_file_path)

# Create instances of the Trip class from dataframe rows and group them by train number and day
trips_by_train_and_day = {}
for index, row in df.iterrows():
    key = (row['train_number'], row['days'])
    if key not in trips_by_train_and_day:
        trips_by_train_and_day[key] = []

    trip = Trip(row['departure_station'],
                row['arrival_station'],
                row['departure_time'],
                row['arrival_time'],
                row['train_number'],
                row['attendance_rate'],
                row['days'],
                row['conductors_available'])
    trips_by_train_and_day[key].append(trip)

# Assign conductors to trips and create journeys for each train and day
for train_day_trips in trips_by_train_and_day.values():
    assign_conductors_to_trips(train_day_trips)
    train_day_journeys = create_journeys(train_day_trips)

    # Print the updated trips list with assigned conductors for each journey
    for journey in train_day_journeys:
        for trip in journey:
            print(trip)
        print('-' * 50)
# Out:
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=233, arrival_time=240, train_number=1, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=2C))
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=260, arrival_time=271, train_number=2, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=271, arrival_time=298, train_number=2, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=300, arrival_time=332, train_number=2, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, train_number=3, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=6F))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, train_number=3, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=We, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=3E))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=6F))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, train_number=3, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, train_number=3, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1E,2E,3E, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, train_number=3, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, train_number=3, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=2E))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=346, arrival_time=368, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=368, arrival_time=382, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=382, arrival_time=398, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=398, arrival_time=408, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=408, arrival_time=410, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=411, arrival_time=427, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=427, arrival_time=440, train_number=3, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=265, arrival_time=300, train_number=3, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=303, arrival_time=340, train_number=3, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=266, arrival_time=296, train_number=4, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=F, arrival_station=E, departure_time=323, arrival_time=352, train_number=4, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=2F))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=283, arrival_time=314, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=373, arrival_time=382, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=383, arrival_time=386, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=387, arrival_time=402, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=402, arrival_time=414, train_number=5, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=293, arrival_time=300, train_number=6, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=6F))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=3F))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=4F))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=300, arrival_time=311, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=311, arrival_time=338, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=350, arrival_time=379, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=380, arrival_time=410, train_number=7, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=2A))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=3A))
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=305, arrival_time=320, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=J, departure_time=320, arrival_time=330, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=K, departure_time=331, arrival_time=334, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=I, departure_time=334, arrival_time=348, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=A, departure_time=349, arrival_time=360, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=A, arrival_station=L, departure_time=362, arrival_time=376, train_number=8, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=5A))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=5A))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=2A))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=3A))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=319, arrival_time=328, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=2A))
# Trip(departure_station=I, arrival_station=K, departure_time=329, arrival_time=345, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=348, arrival_time=350, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=350, arrival_time=361, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=362, arrival_time=374, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=2C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=D, departure_time=320, arrival_time=344, train_number=5, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=345, arrival_time=355, train_number=5, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=C, arrival_station=H, departure_time=355, arrival_time=368, train_number=5, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=3C))
# ...
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=We, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=4F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Th, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=4F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=2G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=3F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=3G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=5A))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=3A))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=0))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=4C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=2F))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Su, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=2E))
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=5F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1E,2E, assigned_conductor=None)
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=423, arrival_time=431, train_number=181, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------

# %%
# assignment of conductors with respect to attendance rate
import pandas as pd
import random

class Trip:
    def __init__(self, departure_station, arrival_station, departure_time, arrival_time, train_number, attendance_rate, days, conductors_available):
        self.departure_station = departure_station
        self.arrival_station = arrival_station
        self.departure_time = departure_time
        self.arrival_time = arrival_time
        self.train_number = train_number
        self.attendance_rate = attendance_rate
        self.days = days
        self.conductors_available = str(conductors_available)  # Convert to string
        self.assigned_conductor = None

    def assign_conductor(self, conductor):
        self.assigned_conductor = conductor

    def __repr__(self):
        return f"Trip(departure_station={self.departure_station}, arrival_station={self.arrival_station}, " \
               f"departure_time={self.departure_time}, arrival_time={self.arrival_time}, train_number={self.train_number}, " \
               f"attendance_rate={self.attendance_rate}, days={self.days}, conductors_available={self.conductors_available}, assigned_conductor={self.assigned_conductor})"

class Conductor:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f"Conductor(name={self.name})"

class FeasibilityCheck:
    def __init__(self, train_number, total_trips, target_count):
        self.train_number = train_number
        self.total_trips = total_trips
        self.target_count = target_count
        self.assigned_count = 0

    def increment_assigned_count(self):
        self.assigned_count += 1

    def is_target_met(self):
        return self.assigned_count >= self.target_count

def assign_conductors_to_trips(trips):
    feasibility_checks = {}  # To keep track of attendance rate for each train
    for trip in trips:
        train_number = trip.train_number
        if train_number not in feasibility_checks:
            # Initialize a feasibility check object for the train
            total_trips = len([t for t in trips if t.train_number == train_number])
            target_count = total_trips // 2  # 50% of trips
            feasibility_checks[train_number] = FeasibilityCheck(train_number, total_trips, target_count)

        feasibility_check = feasibility_checks[train_number]

        # Check if the attendance rate is met for the train
        if not feasibility_check.is_target_met():
            # Find available conductors for the departing station on the given day
            available_conductors = [Conductor(name) for name in trip.conductors_available.split(',') if name != '0']

            # Assign a conductor based on availability or use the previous conductor
            if available_conductors:
                assigned_conductor = available_conductors[0]  # Select the first available conductor
                trip.assign_conductor(assigned_conductor)
                feasibility_check.increment_assigned_count()

            elif feasibility_check.assigned_count < feasibility_check.target_count:
                # If attendance rate is not met and no conductor is available
                print(f"No conductor available for Train {train_number} on Trip {trip.train_number}-{trip.days}.")

        # Check if conductor should continue the journey
        if trip.assigned_conductor:
            departure_time = pd.to_datetime(trip.departure_time)
            arrival_time = pd.to_datetime(trip.arrival_time)

            # Check if the total difference between departure and arrival time is <= 600
            if (arrival_time - departure_time).total_seconds() <= 600:
                # Continue the conductor to the arrival station
                next_trip = next((t for t in trips if t.train_number == train_number and t.days == trip.days and t.departure_station == trip.arrival_station), None)
                if next_trip:
                    next_trip.assign_conductor(trip.assigned_conductor)

# Read data from Excel to dataframe
excel_file_path = 'allday_railway_transformed.xlsx'
df = pd.read_excel(excel_file_path)

# Create instances of the Trip class from dataframe rows and group them by train number and day
trips_by_train_and_day = {}
for index, row in df.iterrows():
    key = (row['train_number'], row['days'])
    if key not in trips_by_train_and_day:
        trips_by_train_and_day[key] = []

    trip = Trip(row['departure_station'],
                row['arrival_station'],
                row['departure_time'],
                row['arrival_time'],
                row['train_number'],
                row['attendance_rate'],
                row['days'],
                row['conductors_available'])
    trips_by_train_and_day[key].append(trip)

# Assign conductors to trips for each train and day
for train_day_trips in trips_by_train_and_day.values():
    assign_conductors_to_trips(train_day_trips)

    # Print the updated trips list with assigned conductors for each journey
    for trip in train_day_trips:
        print(trip)
    print('-' * 50)
# Out:
# Streaming output truncated to the last 5000 lines.
# No conductor available for Train 44 on Trip 44-Mo.
# No conductor available for Train 44 on Trip 44-Mo.
# No conductor available for Train 44 on Trip 44-Mo.
# No conductor available for Train 44 on Trip 44-Mo.
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-Tu.
# No conductor available for Train 44 on Trip 44-Tu.
# No conductor available for Train 44 on Trip 44-Tu.
# No conductor available for Train 44 on Trip 44-Tu.
# No conductor available for Train 44 on Trip 44-Tu.
# No conductor available for Train 44 on Trip 44-Tu.
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-We.
# No conductor available for Train 44 on Trip 44-We.
# No conductor available for Train 44 on Trip 44-We.
# No conductor available for Train 44 on Trip 44-We.
# No conductor available for Train 44 on Trip 44-We.
# No conductor available for Train 44 on Trip 44-We.
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-Th.
# No conductor available for Train 44 on Trip 44-Th.
# No conductor available for Train 44 on Trip 44-Th.
# No conductor available for Train 44 on Trip 44-Th.
# No conductor available for Train 44 on Trip 44-Th.
# No conductor available for Train 44 on Trip 44-Th.
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-Fr.
# No conductor available for Train 44 on Trip 44-Fr.
# No conductor available for Train 44 on Trip 44-Fr.
# No conductor available for Train 44 on Trip 44-Fr.
# No conductor available for Train 44 on Trip 44-Fr.
# No conductor available for Train 44 on Trip 44-Fr.
# Trip(departure_station=L, arrival_station=A, departure_time=517, arrival_time=533, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=521, arrival_time=528, train_number=45, attendance_rate=0.0, days=Su, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Mo.
# No conductor available for Train 46 on Trip 46-Mo.
# No conductor available for Train 46 on Trip 46-Mo.
# No conductor available for Train 46 on Trip 46-Mo.
# No conductor available for Train 46 on Trip 46-Mo.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Tu.
# No conductor available for Train 46 on Trip 46-Tu.
# No conductor available for Train 46 on Trip 46-Tu.
# No conductor available for Train 46 on Trip 46-Tu.
# No conductor available for Train 46 on Trip 46-Tu.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-We.
# No conductor available for Train 46 on Trip 46-We.
# No conductor available for Train 46 on Trip 46-We.
# No conductor available for Train 46 on Trip 46-We.
# No conductor available for Train 46 on Trip 46-We.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Th.
# No conductor available for Train 46 on Trip 46-Th.
# No conductor available for Train 46 on Trip 46-Th.
# No conductor available for Train 46 on Trip 46-Th.
# No conductor available for Train 46 on Trip 46-Th.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Fr.
# No conductor available for Train 46 on Trip 46-Fr.
# No conductor available for Train 46 on Trip 46-Fr.
# No conductor available for Train 46 on Trip 46-Fr.
# No conductor available for Train 46 on Trip 46-Fr.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Sa.
# No conductor available for Train 46 on Trip 46-Sa.
# No conductor available for Train 46 on Trip 46-Sa.
# No conductor available for Train 46 on Trip 46-Sa.
# No conductor available for Train 46 on Trip 46-Sa.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 46 on Trip 46-Su.
# No conductor available for Train 46 on Trip 46-Su.
# No conductor available for Train 46 on Trip 46-Su.
# No conductor available for Train 46 on Trip 46-Su.
# No conductor available for Train 46 on Trip 46-Su.
# Trip(departure_station=F, arrival_station=G, departure_time=539, arrival_time=570, train_number=46, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=571, arrival_time=595, train_number=46, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=596, arrival_time=606, train_number=46, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=606, arrival_time=619, train_number=46, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=619, arrival_time=629, train_number=46, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=629, arrival_time=632, train_number=46, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=633, arrival_time=647, train_number=46, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=I, arrival_station=A, departure_time=648, arrival_time=661, train_number=46, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1C))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-Sa.
# No conductor available for Train 44 on Trip 44-Sa.
# No conductor available for Train 44 on Trip 44-Sa.
# No conductor available for Train 44 on Trip 44-Sa.
# No conductor available for Train 44 on Trip 44-Sa.
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 44 on Trip 44-Su.
# No conductor available for Train 44 on Trip 44-Su.
# No conductor available for Train 44 on Trip 44-Su.
# No conductor available for Train 44 on Trip 44-Su.
# No conductor available for Train 44 on Trip 44-Su.
# Trip(departure_station=A, arrival_station=I, departure_time=541, arrival_time=549, train_number=44, attendance_rate=0.5, days=Su, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=550, arrival_time=564, train_number=44, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=565, arrival_time=568, train_number=44, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=569, arrival_time=579, train_number=44, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=579, arrival_time=590, train_number=44, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=C, arrival_station=D, departure_time=590, arrival_time=600, train_number=44, attendance_rate=0.5, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=601, arrival_time=628, train_number=44, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=631, arrival_time=661, train_number=44, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=542, arrival_time=567, train_number=41, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=568, arrival_time=594, train_number=41, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=542, arrival_time=567, train_number=41, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=568, arrival_time=594, train_number=41, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Mo, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, train_number=47, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, train_number=47, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Tu, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, train_number=47, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, train_number=47, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=We, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, train_number=47, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, train_number=47, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Th, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, train_number=47, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, train_number=47, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Fr, conductors_available=1E,2E,3E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=601, arrival_time=627, train_number=47, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=628, arrival_time=640, train_number=47, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1E))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=543, arrival_time=568, train_number=47, attendance_rate=0.5, days=Su, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=569, arrival_time=596, train_number=47, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1E))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Mo, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Tu, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=We, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Th, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=543, arrival_time=551, train_number=48, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=I, departure_time=544, arrival_time=564, train_number=49, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 50 on Trip 50-Mo.
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, train_number=50, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, train_number=50, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, train_number=50, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, train_number=50, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 50 on Trip 50-Tu.
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, train_number=50, attendance_rate=0.5, days=Tu, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, train_number=50, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, train_number=50, attendance_rate=0.5, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, train_number=50, attendance_rate=0.5, days=Tu, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 50 on Trip 50-We.
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, train_number=50, attendance_rate=0.5, days=We, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, train_number=50, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, train_number=50, attendance_rate=0.5, days=We, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, train_number=50, attendance_rate=0.5, days=We, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 50 on Trip 50-Th.
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, train_number=50, attendance_rate=0.5, days=Th, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, train_number=50, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, train_number=50, attendance_rate=0.5, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, train_number=50, attendance_rate=0.5, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# No conductor available for Train 50 on Trip 50-Fr.
# Trip(departure_station=C, arrival_station=D, departure_time=554, arrival_time=565, train_number=50, attendance_rate=0.5, days=Fr, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=565, arrival_time=592, train_number=50, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=602, arrival_time=627, train_number=50, attendance_rate=0.5, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=628, arrival_time=654, train_number=50, attendance_rate=0.5, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Tu, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=We, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Th, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=574, arrival_time=594, train_number=51, attendance_rate=0.5, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Mo, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Tu, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=We, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Th, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=581, arrival_time=588, train_number=52, attendance_rate=0.0, days=Su, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 53 on Trip 53-Mo.
# No conductor available for Train 53 on Trip 53-Mo.
# No conductor available for Train 53 on Trip 53-Mo.
# No conductor available for Train 53 on Trip 53-Mo.
# No conductor available for Train 53 on Trip 53-Mo.
# Trip(departure_station=F, arrival_station=G, departure_time=599, arrival_time=630, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=631, arrival_time=655, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=D, arrival_station=C, departure_time=656, arrival_time=666, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=C, arrival_station=H, departure_time=666, arrival_time=679, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=H, arrival_station=J, departure_time=679, arrival_time=689, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=J, arrival_station=K, departure_time=689, arrival_time=692, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=K, arrival_station=I, departure_time=693, arrival_time=707, train_number=53, attendance_rate=0.5, days=Mo, conductors_available=0, assigned_conductor=Conductor(name=1C))
# ...
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=We, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Th, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=F, arrival_station=G, departure_time=1473, arrival_time=1505, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=G, arrival_station=D, departure_time=1520, arrival_time=1544, train_number=169, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1F))
# Trip(departure_station=D, arrival_station=C, departure_time=1545, arrival_time=1555, train_number=169, attendance_rate=1.0, days=Su, conductors_available=0, assigned_conductor=Conductor(name=1F))
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Mo, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Tu, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=We, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Th, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Fr, conductors_available=1G,2G,3G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Sa, conductors_available=1G, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=1520, arrival_time=1552, train_number=170, attendance_rate=1.0, days=Su, conductors_available=1G, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 171 on Trip 171-Fr.
# No conductor available for Train 171 on Trip 171-Fr.
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 171 on Trip 171-Sa.
# No conductor available for Train 171 on Trip 171-Sa.
# Trip(departure_station=B, arrival_station=I, departure_time=1384, arrival_time=1404, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1404, arrival_time=1420, train_number=171, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=I, departure_time=1394, arrival_time=1404, train_number=172, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=I, arrival_station=B, departure_time=1414, arrival_time=1434, train_number=173, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1430, arrival_time=1453, train_number=174, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 175 on Trip 175-Fr.
# No conductor available for Train 175 on Trip 175-Fr.
# No conductor available for Train 175 on Trip 175-Fr.
# No conductor available for Train 175 on Trip 175-Fr.
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=Conductor(name=1A))
# --------------------------------------------------
# No conductor available for Train 175 on Trip 175-Sa.
# No conductor available for Train 175 on Trip 175-Sa.
# No conductor available for Train 175 on Trip 175-Sa.
# No conductor available for Train 175 on Trip 175-Sa.
# Trip(departure_station=A, arrival_station=I, departure_time=1435, arrival_time=1445, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=I, arrival_station=K, departure_time=1446, arrival_time=1462, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=K, arrival_station=J, departure_time=1463, arrival_time=1465, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=J, arrival_station=H, departure_time=1466, arrival_time=1476, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# Trip(departure_station=H, arrival_station=C, departure_time=1478, arrival_time=1493, train_number=175, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1A))
# --------------------------------------------------
# No conductor available for Train 176 on Trip 176-Fr.
# No conductor available for Train 176 on Trip 176-Fr.
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 176 on Trip 176-Sa.
# No conductor available for Train 176 on Trip 176-Sa.
# Trip(departure_station=B, arrival_station=I, departure_time=1444, arrival_time=1464, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=None)
# Trip(departure_station=I, arrival_station=K, departure_time=1464, arrival_time=1480, train_number=176, attendance_rate=1.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Fr, conductors_available=1A,2A,3A,4A,5A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=1457, arrival_time=1464, train_number=177, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Fr, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=A, departure_time=1490, arrival_time=1513, train_number=178, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=C, arrival_station=H, departure_time=373, arrival_time=383, train_number=179, attendance_rate=0.0, days=Su, conductors_available=1C,2C,3C,4C, assigned_conductor=None)
# --------------------------------------------------
# No conductor available for Train 9 on Trip 9-Sa.
# Trip(departure_station=C, arrival_station=D, departure_time=375, arrival_time=385, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1C,2C,3C,4C, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=D, arrival_station=G, departure_time=386, arrival_time=413, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=0, assigned_conductor=Conductor(name=1C))
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Sa, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=A, arrival_station=B, departure_time=394, arrival_time=414, train_number=180, attendance_rate=0.0, days=Su, conductors_available=1A,2A,3A, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=G, arrival_station=F, departure_time=420, arrival_time=446, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1G, assigned_conductor=Conductor(name=1G))
# Trip(departure_station=F, arrival_station=E, departure_time=447, arrival_time=474, train_number=9, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1G))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Sa, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1E))
# --------------------------------------------------
# Trip(departure_station=E, arrival_station=F, departure_time=423, arrival_time=452, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1E,2E, assigned_conductor=Conductor(name=1E))
# Trip(departure_station=F, arrival_station=G, departure_time=453, arrival_time=482, train_number=31, attendance_rate=0.5, days=Su, conductors_available=1F,2F,3F,4F,5F,6F, assigned_conductor=Conductor(name=1E))
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=423, arrival_time=431, train_number=181, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=K, arrival_station=I, departure_time=796, arrival_time=811, train_number=182, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Sa, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
# Trip(departure_station=B, arrival_station=A, departure_time=903, arrival_time=911, train_number=183, attendance_rate=0.0, days=Su, conductors_available=0, assigned_conductor=None)
# --------------------------------------------------
